# %% [markdown]
# # :basketball: Installations

# %% [markdown]
# List of installed and used packages:
# - Pandas
# - Pathlib
# - Seaborn
# - Matplotlib
# - UltraLytics
# - CV2 (OpenCV)
# - Albumentations
# - Torch (PyTorch)

# %%
# %pip install pandas

# %%
# %pip install pathlib

# %%
# %pip install seaborn

# %%
# %pip install matplotlib

# %%
# %pip install ultralytics

# %%
# %pip install opencv-python

# %%
# %pip install albumentations

# %%
# %pip install torch
